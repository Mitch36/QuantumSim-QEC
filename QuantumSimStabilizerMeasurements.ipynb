# %% [markdown]
# Example with CX & CZ
# =====================

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
 
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.visualization import plot_histogram

qrd = QuantumRegister(2, "Data")
qra = QuantumRegister(2, "Ancillary")
cr = ClassicalRegister(2,"Syndrome")
qc = QuantumCircuit(qrd, qra, cr)
d1, d2, x1, z1 = 0, 1, 2, 3

qc.h(d1)
qc.cx(d1, d2)

qc.z(d1)
qc.x(d1)

qc.h(x1)
qc.h(z1)

qc.cx(x1, d1)
qc.cx(x1, d2)

qc.cz(z1, d1)
qc.cz(z1, d2)

qc.h(x1)
qc.h(z1)

qc.measure(x1, 0)
qc.measure(z1, 1)

qc.draw("mpl")

# backend = BasicSimulator()
# result = backend.run(qc, shots=20).result()   
# counts = result.get_counts()                    
# plot_histogram(counts)

# %% [markdown]
# Example with CX
# =================

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
 
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.visualization import plot_histogram

qrd = QuantumRegister(2, "Data")
qra = QuantumRegister(2, "Ancillary")
cr = ClassicalRegister(2,"Syndrome")
qc = QuantumCircuit(qrd, qra, cr)
d1, d2, x1, z1 = 0, 1, 2, 3

qc.h(d1)
qc.cx(d1, d2)

qc.z(d1)
qc.x(d1)

qc.cx(d1, x1)
qc.cx(d2, x1)

qc.h(z1)

qc.cx(z1, d1)
qc.cx(z1, d2)

qc.h(z1)

qc.measure(x1, 0)
qc.measure(z1, 1)

qc.draw("mpl")

# backend = BasicSimulator()
# result = backend.run(qc, shots=20).result()   
# counts = result.get_counts()                    
# plot_histogram(counts)

# %% [markdown]
# Example with CZ
# ================

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
 
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.visualization import plot_histogram

qrd = QuantumRegister(2, "Data")
qra = QuantumRegister(2, "Ancillary")
cr = ClassicalRegister(2,"Syndrome")
qc = QuantumCircuit(qrd, qra, cr)
d1, d2, x1, z1 = 0, 1, 2, 3

qc.h(d1)
qc.cx(d1, d2)

qc.z(d1)
qc.x(d1)

qc.h(x1)

qc.cz(x1, d1)
qc.cz(x1, d2)

qc.h(x1)

qc.h(d1)
qc.h(d2)
qc.h(z1)

qc.cz(z1, d1)
qc.cz(z1, d2)

qc.h(d1)
qc.h(d2)
qc.h(z1)

qc.measure(x1, 0)
qc.measure(z1, 1)

qc.draw("mpl")

# backend = BasicSimulator()
# result = backend.run(qc, shots=20).result()   
# counts = result.get_counts()                    
# plot_histogram(counts)
